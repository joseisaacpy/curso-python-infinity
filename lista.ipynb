# %%
# listas

nomes = ['isaac', 'jose', 'maria']
idades = [20, 30, 40]
altura = [1.80, 1.70, 1.60]
tem_cachorro = [True, False, True]
nomes_familia = ['isaac', 'jose', 'maria']

print("-" * 40)
print("LISTAS")
print(f"nomes: {nomes}")
print(f"primeiro nome da lista: {nomes[0]}")

print(f"idades: {idades}")
print(f"alturas: {altura}")
print(f"tem cachorro: {tem_cachorro}")
print(f"nomes familia: {nomes_familia}")
print("-" * 40)
# Out:
# ----------------------------------------
# LISTAS
# nomes: ['isaac', 'jose', 'maria']
# primeiro nome da lista: isaac
# idades: [20, 30, 40]
# alturas: [1.8, 1.7, 1.6]
# tem cachorro: [True, False, True]
# nomes familia: ['isaac', 'jose', 'maria']
# ----------------------------------------
