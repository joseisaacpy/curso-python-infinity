# %% [markdown]
# # Curso de Python da Infinity Big Data

# %%
# tipos
nome = 'isaac'
idade  = 20
altura = 1.80
tem_cachorro = True
nomes_familia = ['isaac', 'jose', 'maria']
perfil_isaac = {
    'nome': nome,
    'idade': idade,
    'altura': altura,
    'tem_cachorro': tem_cachorro,
    'nomes_familia': nomes_familia
}

# imprimir os tipos das variaveis
print(type(nome))
print(type(idade))
print(type(altura))
print(type(tem_cachorro))
print(type(nomes_familia))
print(type(perfil_isaac))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'list'>
# <class 'dict'>
